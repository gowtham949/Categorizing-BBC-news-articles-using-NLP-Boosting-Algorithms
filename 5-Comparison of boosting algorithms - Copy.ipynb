# %%
news_Art_B = {'Boost':{'AB':76.00 , 'GB':81.00 , 'HGB':78.00  , 'CB':84.00  , 'LGBM':73.00},
              'ML':{'SGD':43.00 , 'KNN':70.00 , 'NB':57.00 , 'DT':51.00}}

# %%
import matplotlib.pyplot as news_Art_Fmap
import pandas as news_ArtP

news_Art_BV = news_ArtP.DataFrame(news_Art_B)
news_Art_BV.plot.bar(color=['lightblue', 'tan'])

news_Art_Fmap.legend(loc='lower left')
news_Art_Fmap.xticks(rotation=50)
news_Art_Fmap.ylabel('Acuray')
news_Art_Fmap.title('comparison of boosting algorithms')
news_Art_Fmap.show()

# %% [markdown]
# Boosting algorithm is best compared to ML algorithms, In boosting algorithm cat boost algorithm has highest accuracy 84%
